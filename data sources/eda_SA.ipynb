# %%
import pandas as pd
import numpy as np

# %%
CompleteDataset_df=pd.read_csv("data.csv")

# %%
CompleteDataset_df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# 5               5  183277           E. Hazard   27
# 6               6  177003           L. Modrić   32
# 7               7  176580           L. Suárez   31
# 8               8  155862        Sergio Ramos   32
# 9               9  200389            J. Oblak   25
# 10             10  192119         T. Courtois   26
# 11             11  188545      R. Lewandowski   29
# 12             12  182521            T. Kroos   28
# 13             13  182493            D. Godín   32
# 14             14  167495            M. Neuer   32
# 15             15  215914            N. Kanté   27
# 16             16  211110           P. Dybala   24
# ...

# %%
columnsToBePicked=['Name','Age','Nationality','Overall','Potential']

# %%
PlayerCompleteDataSet=CompleteDataset_df[columnsToBePicked]

# %%
PlayerCompleteDataSet.head()
# Out:
#                 Name  Age Nationality  Overall  Potential
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
